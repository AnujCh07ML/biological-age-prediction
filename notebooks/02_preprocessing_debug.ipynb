# %%
import pandas as pd


def split_features(df: pd.DataFrame):
    
    numerical_cols = df.select_dtypes(
        include=["int64", "float64"]).columns.tolist()
    categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

    return numerical_cols, categorical_cols


def impute_missing_values(df: pd.DataFrame, numerical_cols, categorical_cols):

    df = df.copy()

    # Numerical → median
    for col in numerical_cols:
        median_value = df[col].median()
        df[col].fillna(median_value, inplace=True)

    # Categorical → mode
    for col in categorical_cols:
        mode_value = df[col].mode()[0]
        df[col].fillna(mode_value, inplace=True)

    return df


def preprocess_data(df: pd.DataFrame) -> pd.DataFrame:

    print(f"Before preprocessing: {df.shape}")

    # Step 1: Split features
    numerical_cols, categorical_cols = split_features(df)

    print(f"Numerical columns: {len(numerical_cols)}")
    print(f"Categorical columns: {len(categorical_cols)}")

    # Step 2: Handle missing values
    df = impute_missing_values(df, numerical_cols, categorical_cols)

    print(f"After preprocessing: {df.shape}")

    return df

# %%
df = pd.read_parquet('/Users/anuj/Documents/CodeBase/Bioinformatics_projects/biological-age-prediction/data/interim/nhanes_merged.parquet')

# %%
df
# Out:
#            SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0       62161.0       7.0       2.0       1.0      22.0       NaN       3.0
# 1       62162.0       7.0       2.0       2.0       3.0       NaN       1.0
# 2       62163.0       7.0       2.0       1.0      14.0       NaN       5.0
# 3       62164.0       7.0       2.0       2.0      44.0       NaN       3.0
# 4       62165.0       7.0       2.0       2.0      14.0       NaN       4.0
# ...         ...       ...       ...       ...       ...       ...       ...
# 45457  124818.0      66.0       2.0       1.0      40.0       NaN       4.0
# 45458  124819.0      66.0       2.0       1.0       2.0       NaN       4.0
# 45459  124820.0      66.0       2.0       2.0       7.0       NaN       3.0
# 45460  124821.0      66.0       2.0       1.0      63.0       NaN       4.0
# 45461  124822.0      66.0       2.0       1.0      74.0       NaN       2.0
#
#        RIDRETH3  RIDEXMON  RIDEXAGY  ...  DMDMARTZ      WTINTPRP  \
# 0           3.0       2.0       NaN  ...       NaN           NaN
# 1           1.0       1.0       3.0  ...       NaN           NaN
# 2           6.0       2.0      14.0  ...       NaN           NaN
# 3           3.0       1.0       NaN  ...       NaN           NaN
# 4           4.0       2.0      14.0  ...       NaN           NaN
# ...         ...       ...       ...  ...       ...           ...
# 45457       4.0       1.0       NaN  ...       1.0  21586.596728
# 45458       4.0       2.0       NaN  ...       NaN   1664.919253
# 45459       3.0       2.0       NaN  ...       NaN  14819.783161
# 45460       4.0       1.0       NaN  ...       2.0   4666.817952
# 45461       2.0       2.0       NaN  ...       1.0  14024.476634
#
#            WTMECPRP  LBXHSCRP  LBDHRPLC      WTSAFPRP  LBXNRBC      LBDSATLC  \
# 0               NaN       NaN       NaN           NaN      NaN           NaN
# 1               NaN       NaN       NaN           NaN      NaN           NaN
# 2               NaN       NaN       NaN           NaN      NaN           NaN
# 3               NaN       NaN       NaN           NaN      NaN           NaN
# 4               NaN       NaN       NaN           NaN      NaN           NaN
# ...             ...       ...       ...           ...      ...           ...
# 45457  21666.889837       NaN       NaN           NaN      0.1  5.397605e-79
# 45458   1838.169709       NaN       NaN           NaN      NaN           NaN
# 45459  16497.806674       NaN       NaN           NaN      0.1           NaN
# 45460   4853.430230       NaN       NaN  10704.467871      0.1  5.397605e-79
# 45461  15195.796658       NaN       NaN  36585.328133      0.2  5.397605e-79
#
#            LBDSGTLC      LBDSTBLC
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# ...             ...           ...
# 45457  5.397605e-79  5.397605e-79
# 45458           NaN           NaN
# 45459           NaN           NaN
# 45460  5.397605e-79  5.397605e-79
# 45461  5.397605e-79  5.397605e-79
#
# [45462 rows x 129 columns]
